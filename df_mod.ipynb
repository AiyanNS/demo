# %%
import pandas as pd
import json

# %%
df=pd.read_csv('EMT_map.csv',delimiter=',')
df=df.to_dict(orient='records')
context={'my_list':json.dumps(df)}

# %%
context
# Out:
# {'my_list': '[{"IDESTACION": 3061, "DENOMINACION": "AV.PABLO NERUDA-MALGRAT MAR", "LINEAS": "54, 142, 144", "longitude": -3.6401924340761855, "latitude": 40.39455347688935}, {"IDESTACION": 3065, "DENOMINACION": "SAN CLAUDIO-RAFAEL FERNANDEZ", "LINEAS": "54", "longitude": -3.634450073589064, "latitude": 40.392873398062406}, {"IDESTACION": 3007, "DENOMINACION": "CERRO DEL CASTA\\u00d1AR-MORALZARZAL", "LINEAS": "134", "longitude": -3.712608386411848, "latitude": 40.49587747299382}, {"IDESTACION": 3066, "DENOMINACION": "ANDALUCES-SAN CLAUDIO", "LINEAS": "54", "longitude": -3.6358435983420274, "latitude": 40.39195582459053}, {"IDESTACION": 2948, "DENOMINACION": "CTRA.VILLAVERDE A VALLECAS-AV.ROSALES", "LINEAS": "23, 130", "longitude": -3.6816003187604927, "latitude": 40.36202816231408}, {"IDESTACION": 2953, "DENOMINACION": "CTRA.CCHEL A VILLAVERDE-CENTRO ESCOLAR", "LINEAS": "131", "longitude": -3.71021262319433, "latitude": 40.35576582288262}, {"IDESTACION": 2958, "DENOMINACION": "RAFAELA
# ...
